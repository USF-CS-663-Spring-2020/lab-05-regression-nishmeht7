# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

df = pd.read_csv('Credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  ...  Married         Ethnicity  Balance
# 0             1   14.891   3606  ...      Yes         Caucasian      333
# 1             2  106.025   6645  ...      Yes             Asian      903
# 2             3  104.593   7075  ...       No             Asian      580
# 3             4  148.924   9504  ...       No             Asian      964
# 4             5   55.882   4897  ...      Yes         Caucasian      331
# ..          ...      ...    ...  ...      ...               ...      ...
# 395         396   12.096   4100  ...      Yes         Caucasian      560
# 396         397   13.364   3838  ...       No  African American      480
# 397         398   57.872   4171  ...      Yes         Caucasian      138
# 398         399   37.728   2525  ...      Yes         Caucasian        0
# 399         400   18.701   5524  ...       No             Asian      966
#
# [400 rows x 12 columns]

# %% [markdown]
# INCOME against LIMIT

# %%
df.plot(kind='scatter', x='Income', y='Limit')

# %% [markdown]
# This looks homogenous

# %%
plot = sns.residplot(x='Income', y='Limit', data=df)
plot.set(xlabel='Income', ylabel='Limit')
# Out:
# [Text(0, 0.5, 'Limit'), Text(0.5, 0, 'Income')]

# %%
lin_reg = LinearRegression()
df_1 = df.iloc[:, 1:3]
lin_reg.fit(df_1.drop('Limit', axis=1), df_1.iloc[:,1])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([51.8750206])

# %%
lin_reg.intercept_
# Out:
# 2389.8694089155265

# %% [markdown]
# SLR can be applied giving us a coefficient of 51.875 and an intercept of 2389.8694

# %% [markdown]
# **RATING against LIMIT**

# %%
df.plot(kind='scatter', x='Rating', y='Limit')

# %%
plot1 = sns.residplot(x='Rating', y='Limit', data=df)

# %%
lin_reg1 = LinearRegression()
df_2 = df.iloc[:, [2,3]]
lin_reg1.fit(df_2.drop('Limit', axis=1), df.iloc[:,0])
lin_reg1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg1.coef_
# Out:
# array([0.01642817])

# %%
lin_reg1.intercept_
# Out:
# 194.66898472231955

# %% [markdown]
# Since the data is homoegenous we can apply SLR with a coefficient of 0.016 and an intercept of 194.6689

# %% [markdown]
# **CARDS against LIMIT**

# %%
df.plot(kind='scatter', x='Cards', y='Limit')

# %%
plot2 = sns.residplot(x='Cards', y='Limit', data=df)

# %% [markdown]
# No homogenuity in data distribution, so cannot use SLR
#
# ---

# %% [markdown]
# **AGE agsint LIMIT**

# %%
df.plot(kind='scatter', x='Age', y='Limit')

# %%
plot3 = sns.residplot(x='Age', y='Limit', data=df)

# %% [markdown]
# No homogenuity in data distribution, so cannot use SLR
#
# ---

# %% [markdown]
# **EDUCATION against LIMIT**

# %%
df.plot(kind='scatter', x='Education', y='Limit')

# %%
plot4 = sns.residplot(x='Education', y='Limit', data=df)

# %% [markdown]
# No homogenuity in data distribution, so cannot use SLR
